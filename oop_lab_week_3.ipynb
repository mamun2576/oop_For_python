# %% [markdown]
# <a href="https://colab.research.google.com/github/mamun2576/oop_For_python/blob/master/oop_lab_week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **USER DEFINED FUNCTION**
#
# ---
#
#
#
# ---

# %%
def function(m1,m2):
  sum=m1+m2
  return sum
m1=int(input("Enter the number: "))
m2=int(input("Enter the number: "))
result=function(m1,m2)
print("The sum is ",result)
# Out:
# Enter the number: 6
# Enter the number: 4
# The sum is  10

# %% [markdown]
# **FUNCTION WITH MULTIPLE PARAMETERS**
#
# ---
#
#
#
# ---

# %%
def divisor(x,y,m):
    if x%m==0 and y%m==0:
        print("%d & %d are divisible by %d"%(x,y,m))
    elif x%m==0:
        print("only %d is divisible by %d"%(x,m))
    elif y%m==0:
        print("only %d is divisible by %d"%(y,m))
    else:
       print("none of %d & %d is divisible by %d"%(x,y,m))

divisor(10,20,5)
divisor(12,20,5)
divisor(10,22,5)
divisor(20,45,3)
# Out:
# 10 & 20 are divisible by 5
# only 20 is divisible by 5
# only 10 is divisible by 5
# only 45 is divisible by 3

# %% [markdown]
# **FUNCTION WITHOUT PARAMETER**
#
# ---
#
#
#
# ---

# %%
def add():
  m=1+3
  return m
m1=add()
print(m1)
# Out:
# 4

# %% [markdown]
# **Function with default parameter value**
#
# ---
#
#
#
# ---

# %%
def check(a=0):
    if a==0:
        print("Zero")
    elif a>0:
        print("Positive")
    else:
        print("Negative")

check()     
check(-8)
# Out:
# Zero
# Negative

# %% [markdown]
# **Global scope**
#
# ---
#
#
#
# ---

# %%
m=50

def global_scope():
    print(m)

print(m)
global_scope()
# Out:
# 50
# 50

# %% [markdown]
# **Global scope**
#
# ---
#
#
#
# ---

# %%
def global_scope():
    global x
    x=50

global_scope()
print(x)
# Out:
# 50

# %% [markdown]
# **Math module**
#
#
# ---
#
#
#
# ---

# %%
import math

print(math.pi)          

x=5.2
print(math.ceil(x))     
print(math.floor(x))    
print(math.sin(78))   

print(math.pow(2,3))    

print(math.sqrt(16))
# Out:
# 3.141592653589793
# 6
# 5
# 0.5139784559875352
# 8.0
# 4.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **csv module covid-confirmed-cases-since-100th-case**
#
# ---
#
#
#
# ---

# %%
import csv

with open('gdrive/My Drive/Colab Notebooks/covid-confirmed-cases-since-100th-case.csv', newline='') as csvfile:
    tmp = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in tmp:
        print(', '.join(row))
# Out:
# Streaming output truncated to the last 5000 lines.
# Nepal,NPL,"Jan, 12,, 2020",0,
# Nepal,NPL,"Jan, 13,, 2020",0,
# Nepal,NPL,"Jan, 14,, 2020",0,
# Nepal,NPL,"Jan, 15,, 2020",0,
# Nepal,NPL,"Jan, 16,, 2020",0,
# Nepal,NPL,"Jan, 17,, 2020",0,
# Nepal,NPL,"Jan, 18,, 2020",0,
# Nepal,NPL,"Jan, 19,, 2020",0,
# Nepal,NPL,"Jan, 20,, 2020",0,
# Nepal,NPL,"Jan, 21,, 2020",0,
# Nepal,NPL,"Jan, 22,, 2020",0,
# Nepal,NPL,"Jan, 23,, 2020",0,
# Nepal,NPL,"Jan, 24,, 2020",0,
# Nepal,NPL,"Jan, 25,, 2020",1,
# Nepal,NPL,"Jan, 26,, 2020",1,
# Nepal,NPL,"Jan, 27,, 2020",1,
# Nepal,NPL,"Jan, 28,, 2020",1,
# Nepal,NPL,"Jan, 29,, 2020",1,
# Nepal,NPL,"Jan, 30,, 2020",1,
# Nepal,NPL,"Jan, 31,, 2020",1,
# Nepal,NPL,"Feb, 1,, 2020",1,
# Nepal,NPL,"Feb, 2,, 2020",1,
# Nepal,NPL,"Feb, 3,, 2020",1,
# Nepal,NPL,"Feb, 4,, 2020",1,
# Nepal,NPL,"Feb, 5,, 2020",1,
# Nepal,NPL,"Feb, 6,, 2020",1,
# Nepal,NPL,"Feb, 7,, 2020",1,
# Nepal,NPL,"Feb, 8,, 2020",1,
# Nepal,NPL,"Feb, 9,, 2020",1,
# ...

# %%
import pandas as panda

# %%
tmp=panda.read_csv('gdrive/My Drive/Colab Notebooks/covid-confirmed-cases-since-100th-case.csv')
# Out:
#             Entity Code  ...  (cases)  Days since the 100th confirmed case (days)
# 0      Afghanistan  AFG  ...      0.0                                         NaN
# 1      Afghanistan  AFG  ...      0.0                                         NaN
# 2      Afghanistan  AFG  ...      0.0                                         NaN
# 3      Afghanistan  AFG  ...      0.0                                         NaN
# 4      Afghanistan  AFG  ...      0.0                                         NaN
# ...            ...  ...  ...      ...                                         ...
# 13327     Zimbabwe  ZWE  ...     17.0                                         NaN
# 13328     Zimbabwe  ZWE  ...     17.0                                         NaN
# 13329     Zimbabwe  ZWE  ...     23.0                                         NaN
# 13330     Zimbabwe  ZWE  ...     24.0                                         NaN
# ...

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13332 entries, 0 to 13331
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      13332 non-null  object
#  1   Code                                        11611 non-null  object
#  2   Date                                        13332 non-null  object
#  3    (cases)                                    13323 non-null  float64
#  4   Days since the 100th confirmed case (days)  4861 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 520.9+ KB

# %%
tmp.head(5)
# Out:
#         Entity Code  ...  (cases)  Days since the 100th confirmed case (days)
# 0  Afghanistan  AFG  ...      0.0                                         NaN
# 1  Afghanistan  AFG  ...      0.0                                         NaN
# 2  Afghanistan  AFG  ...      0.0                                         NaN
# 3  Afghanistan  AFG  ...      0.0                                         NaN
# 4  Afghanistan  AFG  ...      0.0                                         NaN
#
# [5 rows x 5 columns]

# %%
tmp.tail(5)
# Out:
#          Entity Code  ...  (cases)  Days since the 100th confirmed case (days)
# 13327  Zimbabwe  ZWE  ...     17.0                                         NaN
# 13328  Zimbabwe  ZWE  ...     17.0                                         NaN
# 13329  Zimbabwe  ZWE  ...     23.0                                         NaN
# 13330  Zimbabwe  ZWE  ...     24.0                                         NaN
# 13331  Zimbabwe  ZWE  ...     24.0                                         NaN
#
# [5 rows x 5 columns]

# %%
tmp.shape
# Out:
# (13332, 5)
